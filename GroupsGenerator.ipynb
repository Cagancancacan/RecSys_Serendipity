# %%
from sklearn.cluster import KMeans
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
import numpy as np

style.use("ggplot")
# %matplotlib inline

# %%
data  = np.random.randn(40000, 20)

# %%
n_clusters = 10
k_means = KMeans(n_clusters=n_clusters).fit(data)

centroids = k_means.cluster_centers_
labels = k_means.labels_

print(centroids)
print(labels)
# Out:
# [[ 0.51388769 -0.12686394 -0.02076073 -0.16885697 -0.35485276  0.39986627
#   -0.11358617  0.4659908   0.03962075  0.68398061  0.38265504  0.08835407
#    0.32099981  0.34563758 -0.30867503 -0.35896596 -0.57068941 -0.26513044
#    0.56820512  0.41872566]
#  [ 0.24130816 -0.19488575 -0.44036369  0.0380707  -0.0907074   0.70023601
#   -0.40744305  0.18349213 -0.06096692 -0.39609007 -0.61393537  0.28212894
#   -0.74725385 -0.55959728  0.19432768  0.03557819  0.11457923 -0.34843882
#   -0.09846166  0.31771167]
#  [ 0.41450887  0.36532251 -0.08126045  1.07974039 -0.17132752 -0.13567151
#   -0.34786827 -0.25728482  0.15553516  0.23867571 -0.01453846 -0.05236438
#    0.0693132   0.37575425  0.59772593 -0.11211314  0.52345078  0.21917838
#    0.223631   -0.32117941]
#  [-0.57425059  0.03553029  0.20234983 -0.64993207  0.23530703 -0.19006035
#   -0.39900558  0.22120618  0.32809659  0.29732274  0.01333428  0.09808746
#   -0.1485018   0.28129129  0.61301373  0.77360912 -0.17659982 -0.10620848
#    0.27064872 -0.44971441]
#  [-0.21405243  0.00847151  0.3317056  -0.01957069 -0.12704914 -0.66052179
#    0.30318409 -0.65902934 -0.2101046   0.61150057 -0.25571941 -0.36984825
#   -0.72272446 -0.35073125 -0.09202338 -0.40990166 -0.36068566 -0.03526073
#   -0.07898266  0.24633879]
#  [-0.41923513  0.20046156 -0.17519762  0.0660269  -0.25978059 -0.01195198
#   -0.19884022 -0.35079347  0.69516662 -0.6305419   0.83046316  0.14043025
#    0.07347149 -0.50792988 -0.48400962 -0.18287937 -0.13364472  0.20524028
#    0.13368013 -0.25177032]
#  [-0.42917822 -0.34453228 -0.39938371 -0.10288892  0.20458441  0.42222793
#    0.63306869 -0.60068717 -0.26265468  0.30984199 -0.10606377  0.36967829
#    0.36170445  0.43413708 -0.36466251  0.37000819  0.55957364  0.06243695
#   -0.05830112  0.11859575]
#  [ 0.37815037 -0.35744621 -0.29712412  0.09373953  0.38814616 -0.54595851
#    0.33643859  0.17696476  0.07220895 -0.66549334  0.1567405   0.03276308
#    0.06829446  0.57854199  0.13422229  0.0813108  -0.53278068 -0.21525547
#   -0.77443917  0.2962336 ]
#  [ 0.15310486 -0.19623324  0.43025034 -0.15225583  0.53045541  0.06962372
#   -0.30090491 -0.04116988 -0.42273233 -0.3468833  -0.50843883 -0.56431519
#    0.823235   -0.39838031 -0.15996901 -0.34886217 -0.00637667 -0.13128738
#    0.15691369 -0.46804421]
#  [-0.03061255  0.57506231  0.41098037 -0.19886041 -0.24350072 -0.00458245
#    0.43789838  0.93425469 -0.38408134 -0.1225838   0.13882086 -0.0562153
#   -0.11786261 -0.15046622 -0.06343581  0.05303981  0.51054919  0.68474795
#   -0.37719861  0.12321213]]
# [4 8 9 ... 5 1 5]

# %%
data['labels'] = labels

group1 = data[data['labels']==1].plot( kind='scatter', x='x', y='y', color='DarkGreen', label="Group 1" )
group2 = data[data['labels']==0].plot( kind='scatter', x='x', y='y', color='Brown', ax=group1, label="Group 2" )
group1.legend(loc='upper center', bbox_to_anchor=(0.5, 1.05),
          ncol=3, fancybox=True, shadow=True)
plt.scatter(centroids[:, 0],centroids[:, 1], marker = "x", s=150, linewidths = 5, zorder = 10)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 data['labels'] = labels
#       3 group1 = data[data['labels']==1].plot( kind='scatter', x='x', y='y', color='DarkGreen', label="Group 1" )
#       4 group2 = data[data['labels']==0].plot( kind='scatter', x='x', y='y', color='Brown', ax=group1, label="Group 2" )
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
data = pd.DataFrame(data)
groups = [] #list containing n dataframes
for i in range(0, n_clusters):
    mask = labels == i
    groups.append(data[mask])
print(data)
# Out:
#              0         1         2         3         4         5         6   \
# 0      0.289320  0.539530 -0.611704  1.010779  0.053943 -0.046776  0.835598
# 1     -0.185119 -0.934377  0.584961 -0.345375 -0.789346 -0.782757 -0.070902
# 2      1.221936  0.787934  0.540570  0.219922 -0.113969  0.430531 -1.215433
# 3      0.288800 -1.758201 -0.449938 -0.132077 -0.042328 -0.135253 -1.128745
# 4      1.532024  0.021991  1.230691  1.059216 -1.526469  1.270501  0.140722
# ...         ...       ...       ...       ...       ...       ...       ...
# 39995 -1.093023  0.151075  0.651495  0.538766  0.930594 -1.232176  1.177790
# 39996  0.012710  0.587288 -0.367407 -1.096774 -0.119976  0.406798 -0.259168
# 39997  0.151909  1.284541 -1.503624 -1.068356 -0.653873 -0.427716 -0.328151
# 39998  0.501411 -0.552511 -0.001232  0.368530  0.213982 -0.068123 -1.368890
# 39999 -1.413480 -0.148917  1.478942 -1.278262  1.100280  1.007414  0.124742
#
#              7         8         9         10        11        12        13  \
# 0     -0.417047 -0.230113  0.142847  0.947023 -1.227134 -2.086563 -0.307283
# 1     -0.195984 -1.241290 -1.787420 -0.109674  0.725485  0.863291  0.027273
# 2      0.981878 -0.136035 -1.295575  1.499798 -0.141392  1.484852 -0.249348
# 3      0.237937 -0.383364 -0.382845  1.575374  0.268196  0.085956 -0.425289
# 4     -0.017886  0.330972 -2.622328 -2.120354 -0.689288  1.757671 -2.539693
# ...         ...       ...       ...       ...       ...       ...       ...
# 39995  1.295944  1.452321 -0.672772  0.372657  0.769700  1.109549 -1.578563
# 39996 -0.308106  0.028402  1.243837 -0.099472 -1.543916 -1.328705  1.309211
# 39997 -2.646318  1.115977 -0.677848  0.882572  0.752720 -0.453918  0.137156
# 39998 -1.017591 -1.737847  0.051054  0.289819 -0.187987 -1.192690 -0.998103
# 39999  1.146947  1.701179  0.214448  1.481054  0.138314 -1.102230 -1.166446
#
#              14        15        16        17        18        19
# 0     -1.686699  0.956861  0.128485  1.270712  0.170548  0.197870
# 1     -0.763104 -0.033570 -1.197439 -1.149972  2.428402 -1.851216
# 2      0.753356  0.130836  2.385457  1.051406  0.383654 -0.249459
# 3     -1.154743 -0.964868  0.510500  0.199318  0.132170  0.034492
# 4     -0.212024 -0.000666 -0.126912 -0.790530 -1.181021  0.024654
# ...         ...       ...       ...       ...       ...       ...
# 39995  1.190556  0.369705  0.521863  1.068170 -1.412986  0.273014
# 39996 -1.279985  0.750073  1.042486 -1.113251  0.407956  0.713065
# 39997  0.740248  0.990537  0.421099 -1.025728  0.440610  0.201456
# 39998 -0.382749  1.707620  0.464128 -0.139415  0.850124  1.619991
# 39999  0.151665 -1.248387  1.585853 -1.273858  0.551667  0.126656
#
# [40000 rows x 20 columns]
