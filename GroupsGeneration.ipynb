# %%
from sklearn.datasets import load_digits
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
import numpy as np
from IPython.display import display

style.use("ggplot")
# %matplotlib inline

#Load Data
data_folder = "C:/Users/roman/OneDrive/Bureau/UM/BA/Y3/P1/RS/Group Assignment/archive"
average_ratings_per_user_for_each_genre_df = pd.read_csv(data_folder + "/data.csv")
data_df = average_ratings_per_user_for_each_genre_df.fillna(0)
data_df = data_df.drop(8041)
display(data_df)


n_clusters = 20
kmeans = KMeans(n_clusters=n_clusters).fit(data_df)

centroids = kmeans.cluster_centers_
labels = kmeans.labels_

print(labels)
print(labels.min())
print(labels.max())
print(len(labels))

#PLOT
#data = load_digits().data_df
pca = PCA(2) #change?
df = pca.fit_transform(data_df)

u_labels = np.unique(labels)

#plotting the results:
for i in u_labels:
    plt.scatter(df[labels == i , 0] , df[labels == i , 1] , label = i)
plt.legend()
plt.show()
# Out:
#             0         1         2         3         4         5         6  \
# 0         3.0  4.363636  4.000000  4.057692  3.750000  4.300000  4.666667
# 1         6.0  4.500000  1.000000  3.666667  5.000000  3.000000  0.000000
# 2         8.0  4.666667  3.600000  3.640000  3.714286  3.428571  4.800000
# 3        10.0  3.000000  4.000000  4.000000  4.000000  4.000000  3.818182
# 4        11.0  4.083333  3.900000  3.748276  4.090909  3.887324  3.892857
# ...       ...       ...       ...       ...       ...       ...       ...
# 8036  22352.0  3.366279  3.631313  3.362840  3.676471  3.766667  3.724490
# 8037  22354.0  4.076923  4.333333  3.944444  4.500000  4.714286  4.684211
# 8038  22357.0  3.492537  3.776596  3.671587  3.780000  3.685185  3.703704
# 8039  22363.0  2.023810  1.265625  1.687097  1.526786  1.213675  2.272727
# 8040  22364.0  3.000000  3.333333  3.071429  3.250000  3.000000  3.000000
#
#              7         8         9  ...        11        12   13        14  \
# ...

# %%
data_df['labels'] = labels

print(data_df)

groups = [20]
for i in range(0, 20):
    groups[i] = groups.append([])

for i in range(0, data_df.shape[0]):
    if data_df.at[i,'labels' == 0]:
        groups[0].append(data_df[i, 0])
    elif data_df.at[i,'labels' == 1]:
        groups[1].append(data_df[i, 1])
    elif data_df.at[i,'labels' == 2]:
        groups[2].append(data_df[i, 1])
    elif data_df.at[i,'labels' == 3]:
        groups[3].append(data_df[i, 1])
    elif data_df.at[i,'labels' == 4]:
        groups[4].append(data_df[i, 1])
    elif data_df.at[i,'labels' == 5]:
        groups[5].append(data_df[i, 1])
    elif data_df.at[i,'labels' == 6]:
        groups[6].append(data_df[i, 1])
    elif data_df.at[i,'labels' == 7]:
        groups[7].append(data_df[i, 1])
    elif data_df.at[i,'labels' == 8]:
        groups[8].append(data_df[i, 1])
    elif data_df.at[i,'labels' == 9]:
        groups[9].append(data_df[i, 1])
    elif data_df.at[i,'labels' == 10]:
        groups[10].append(data_df[i, 1])
    elif data_df.at[i,'labels' == 11]:
        groups[11].append(data_df[i, 1])
    elif data_df.at[i,'labels' == 12]:
        groups[12].append(data_df[i, 1])
    elif data_df.at[i,'labels' == 13]:
        groups[13].append(data_df[i, 1])
    elif data_df.at[i,'labels' == 14]:
        groups[14].append(data_df[i, 1])
    elif data_df.at[i,'labels' == 15]:
        groups[15].append(data_df[i, 1])
    elif data_df.at[i,'labels' == 16]:
        groups[16].append(data_df[i, 1])
    elif data_df.at[i,'labels' == 17]:
        groups[17].append(data_df[i, 1])
    elif data_df.at[i,'labels' == 18]:
        groups[18].append(data_df[i, 1])
    elif data_df.at[i,'labels' == 19]:
        groups[19].append(data_df[i, 1])

print(groups)
# Out:
#             0         1         2         3         4         5         6  \
# 0         3.0  4.363636  4.000000  4.057692  3.750000  4.300000  4.666667
# 1         6.0  4.500000  1.000000  3.666667  5.000000  3.000000  0.000000
# 2         8.0  4.666667  3.600000  3.640000  3.714286  3.428571  4.800000
# 3        10.0  3.000000  4.000000  4.000000  4.000000  4.000000  3.818182
# 4        11.0  4.083333  3.900000  3.748276  4.090909  3.887324  3.892857
# ...       ...       ...       ...       ...       ...       ...       ...
# 8036  22352.0  3.366279  3.631313  3.362840  3.676471  3.766667  3.724490
# 8037  22354.0  4.076923  4.333333  3.944444  4.500000  4.714286  4.684211
# 8038  22357.0  3.492537  3.776596  3.671587  3.780000  3.685185  3.703704
# 8039  22363.0  2.023810  1.265625  1.687097  1.526786  1.213675  2.272727
# 8040  22364.0  3.000000  3.333333  3.071429  3.250000  3.000000  3.000000
#
#              7         8         9  ...        12   13        14        15  \
# ...
